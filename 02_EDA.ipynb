# %% [markdown]
# Explanation of project.

# %%
#import relevant packages

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import missingno as msno

# %%
#read in CSV
df = pd.read_csv('eda_data.csv', index_col=0)

#ensure all columns are displayed throughout exploration
pd.set_option('display.max_columns', None)

# %%
df.head()
# Out:
#     Sale Date           Item Name  Quantity  Price Coupon Code Coupon Details  \
# 0  12/14/2020  Shiba Inu Postcard         1   3.49         NaN            NaN
# 1  12/13/2020   Age Modifier Card         1   3.99         NaN            NaN
# 2  12/13/2020      Christmas Card         1   3.99         NaN            NaN
# 3  12/13/2020   Age Modifier Card         1   3.99         NaN            NaN
# 4  12/12/2020      Christmas Card         1   3.99         NaN            NaN
#
#    Discount Amount  Delivery Discount  Order Delivery  Order Sales Tax  \
# 0              0.0                0.0            0.00              0.0
# 1              0.0                0.0            0.00              0.0
# 2              0.0                0.0            0.00              0.0
# 3              0.0                0.0            0.99              0.0
# 4              0.0                0.0            0.00              0.0
#
#    Item Total  Transaction ID  Listing ID   Date Paid Date Posted  \
# ...

# %% [markdown]
# ## Exploration Structure
#
# Now that we've uploaded our cleaned data, we'll want to explore the data further while continuing to clean the dataframe. We'll take the following steps:
#
# ### Initial Exploration
#
# * Look at the dtypes of the columns and convert where appropriate
# * Describe the numeric columns
# * Look at the distribution of NaNs and drop where appropriate
# * Drop the 'Listing ID' column since it's repeating the info in the 'item name' column
# * Drop the 'Date Paid' column since it is the same as the 'Sale Date' column
#
# -Value counts of columns
# -Bar charts of 'has ccounts', '
